# %%
raw = "This is a string of most radical stringabilityness"

# %%
for char in raw:
    if not char in ("aeiou"):
        print(char, end="")
# Out:
# Ths s  strng f mst rdcl strngbltynss

# %%
print(raw[:16])
# Out:
# This is a string
